# %% [markdown]
# **CLASS TASK-01**

# %%
#1.1

my_string=input("Enter your string:")

my_int= int(input("Enter your number:"))

print(my_string)
print(my_int)
# Out:
# Enter your string:hello world
# Enter your number:21
# hello world
# 21

# %%
#1.2

num1= int(input("Enter your first number: "))
num2= int(input("Enter your second number: "))

sum=num1+num2
mult= num1*num2

print("Summation:",sum)
print("Multiplication:",mult)
# Out:
# Enter your first number: 10
# Enter your second number: 5
# Summation: 15
# Multiplication: 50

# %%
#1.3

num1=int(input("Enter your first number: "))
num2= float(input("Enter your second numberr: "))

sum= num1+num2
sub= num1-num2

print( sum," ", sub)
# Out:
# Enter your first number: 4
# Enter your second numberr: 5
# 9.0   -1.0

# %%
#1.4

num1= int(input("Enter your first number: "))
num2= int(input("Enter your second number: "))

num2= float(num2)

num1=str(num1)
num2=str(num2)

s_sum= num1+num2

print(s_sum)
# Out:
# Enter your first number: 2
# Enter your second number: 3
# 23.0

# %% [markdown]
# **Class Task 2: Playing With Operators**

# %%
num1= int(input("Enter your first number: "))
num2= int(input("Enter your second number: "))

expo= num1 ** num2

#print(num1,"^",num2,":", expo)

print(f"{num1} ^ {num2} :", expo)
# Out:
# Enter your first number: 2
# Enter your second number: 3
# 2 ^ 3 : 8
# 2 ^ 3 : 8

# %% [markdown]
# **Class Task 3: Calculating Maximum Weight**

# %%
weight=int(input("Enter your weight:"))

per_corner= weight //4

max_weight = per_corner * 4

print(max_weight)
# Out:
# Enter your weight:23
# 20

# %% [markdown]
# **Class Evaluation Task 1: Operator Precedence**

# %%
a= int(input("Enter your first number: "))
b= int(input("Enter your second number: "))
c= int(input("Enter your first number: "))
d= float(input("Enter your second number: "))

result= a**c + (2*b) * (a//2) - d/3

print(int(result))
# Out:
# Enter your first number: 2
# Enter your second number: 6
# Enter your first number: 8
# Enter your second number: 1.3
# 267

# %% [markdown]
# **Class Evaluation Task 2: Student Info**

# %%
from re import A
first_name = input("Enter your first name: ")
last_name = input("Enter your last name: ")

age= int(input("Enetr your age: "))

cgpa= float(input("Enter your CGPA: "))

last_name= "Rahman"

name= first_name+" "+last_name

age= age-2

cgpa= cgpa + 0.25

print()

print("Name:", name )
print("Age:", age)
print("CGPA:" , cgpa)
# Out:
# Enter your first name: Labiba
# Enter your last name: Arif
# Enetr your age: 23
# Enter your CGPA: 3.7
#
# Name: Labiba Rahman
# Age: 21
# CGPA: 3.95

# %% [markdown]
# **Home Task 3: Chocolate Dilemma**

# %%
choc=int(input("Enter your total amount of chocolate:"))

remain= choc%3

new_choc= choc-remain

each_friend= new_choc / 3

print(f"Each friend will receive {int(each_friend)} chocolates")

print(f"The number of remaining chocolates is {remain}")
# Out:
# Enter your total amount of chocolate:90
# Each friend will receive 30 chocolates
# The number of remaining chocolates is 0

# %%
choc=int(input("Enter your total amount of chocolate:"))

each_friend= choc //3
remainchoc= choc % 3

print(f"Each friend will receive {each_friend} chocolates")

print(f"The number of remaining chocolates is {remainchoc}")
# Out:
# Enter your total amount of chocolate:90
# Each friend will receive 30 chocolates
# The number of remaining chocolates is 0

# %%
x=10
y=15
print(x, end="*")
print(y)
print(x)

print(4/2)
# Out:
# 10*15
# 10
# 2.0

# %%
print ("Hi" * 3)
# Out:
# HiHiHi

# %%
print (-5 / 2)
# Out:
# -2.5

# %%
a = True
b = False

print (a and b)

print (a and not b)
# Out:
# False
# True

# %%
x, y = 6, 10
y=x

print(y)
print (x <= y)

x-=2
x=x+2
x//=1

print(x//1)

print(x)
# Out:
# 6
# True
# 6
# 6

# %%
a = True
b = False
print (a)
print ("b")
# Out:
# True
# b

# %%
x=6
y=10
a=Trueb=False
y=x
print(x)
print(y)
print("b")
print(y>=x)
x-=2
x=x+2
x//=1
print(x)
print(x!=y and a)

print(x*y**2)
print(x+5*4%2-1)

print(x==y*2//2-2**(2-1))

print(x-((x+y%2)*3)//2)
# Out:
# 6
# 6
# b
# True
# 6
# False
# 216
# 5
# False
# -3

# %%
print("Hello","Hi",end=5)
print("yoo")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-35-d814f2423672> in <cell line: 1>()
# ----> 1 print("Hello","Hi",end=5)
#       2 print("yoo")
#
# TypeError: end must be None or a string, not int

# %%
print("Hi"*5)

x=5
print(6+int(x))
# Out:
# HiHiHiHiHi
# 11

# %%
a=True
b=False
print(a and not b)
# Out:
# True

# %%
v= 4>3-1
print(v)
# Out:
# True
