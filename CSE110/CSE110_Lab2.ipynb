# %%
#Task1

num=int(input("Please, Enter your number: "))

if num%2 ==0:
  print('The Number is Even')
else:
  print("The number is Odd")
# Out:
# Please, Enter your number: -44
# The Number is Even

# %%
#Task2

num1= int(input("Please, Enter your first number : "))
num2= int(input("Please, Enter your second number: "))

if num1 > num2:
  print("First is greater")
elif num1 < num2:
  print("Second is greater")
else:
  print("The numbers are equal")
# Out:
# Please, Enter your first number : 67
# Please, Enter your second number: 67
# The numbers are equal6

# %%
#Task3

num=int(input("Enter your number:"))

if num%2==0 or num %5 ==0:
  print(num)
else:
  print("Not a multiple of 2 OR 5")
# Out:
# Enter your number:6
# 6

# %%
#Task4

num=int(input("Enter your number:"))

if num%2==0 and num %5 ==0:
  print(num)
else:
  print("Not a multiple of 2 and 5 both")
# Out:
# Enter your number:15
# Not a multiple of 2 and 5 both

# %%
#Task5

cgpa=float(input("Please, enter your CGPA:"))
credits= int(input("Please,enter your Completed Credits:"))
#cgpa=float(input("Please, enter your CGPA:"))

if credits <30:
  print("The student is not eligible for a waiver")
else:
  if cgpa < 3.8:
    print("The student is not eligible for a waiver")

  elif 3.8<= cgpa<=3.89:
    print("The student is eligible for a waiver of 25 percent")
  elif 3.90<= cgpa <= 3.94:
    print("The student is eligible for a waiver of 50 percent")
  elif 3.95 <= cgpa <=3.99:
    print("The student is eligible for a waiver of 75 percent")
  elif cpga==4:
    print("The student is eligible for a waiver of 100 percent")
# Out:
# Please, enter your CGPA:3.80
# Please,enter your Completed Credits:30
# The student is eligible for a waiver of 25 percent

# %%
#task5

num1 = 10
num2 = -3
num3 = -1
sum = num1 + num2 + num3
if (num3 < 0):
    print(num3 * -2)
else:
    print(sum)
if (num1 < 5):
    print(num1 + 10)
elif (num2 == -3):
    num2 = num1
    print(num2)
else:
    print(num1 + num2 + num3)
if (num1 > 15):
    print(num1)
elif (num2 == 0):
    print(num2 + num3)
else:
    print(num3)
if (sum != 0):
    print(100)
else:
    print(sum + 100)
if (num1 > 0 and num2 < 0):
    print(num1 == num2)
else:
    print("False")
# Out:
# 2
# 10
# -1
# 100
# False

# %%
var1 = var2 = True
var3 = var4 = var5 = False
result1 = result2 = result3 = True
result4 = result5 = False
var1 = 4 > 3 - 1
var2 = False and var1
var3 = True
var4 = False
var5 = not(var3 or var4)
result1 = (var1 or var2) and (8 * 10 > 45)
result2 = (var1 or var2) and (result1 and False)
result3 = (var1 and not result1) or result2
result4 = (var1 or var2) or not((var5 and var1) and False)
result5 = (not var1 and var4) and (result3 or var3)

# %%
#Class Evaluation Task1

hours= int(input("Please, Enter your Working Hours:"))

salary=0

if hours < 0:
  print("Hours cannot be negative")
elif hours > 168:
  print("Impossible to work more than 168 hours weekly")
elif hours <= 40:
  salary= 200*hours
  print(salary)
else:
  salary= 8000 +(hours-40)*300
  print(salary)

#print(salary)
# Out:
# Please, Enter your Working Hours:-45
# Hour cannot be negative

# %%
#Class Evaluation Task1 (second)

hours= int(input("Please, Enter your Working Hours:"))

salary=0

if hours < 0:
  print("Hour cannot be negative")

else:

  if hours > 168:
    print("Impossible to work more than 168 hours weekly")

  else:

    if hours <= 40:
      salary= 200*hours
      print(salary)

    else:
      salary= 8000 +(hours-40)*300
      print(salary)

#print(salary)
# Out:
# Please, Enter your Working Hours:170
# Impossible to work more than 168 hours weekly

# %%
#Class Evaluation Task2

seconds=int(input("Please,Enter your Seconds:"))

hours= seconds // 3600
seconds= seconds % 3600

mins= seconds //60
seconds= seconds %60

print(f"Hours:{hours}\nMinutes:{mins} \nSeconds:{seconds}")
# Out:
# Please,Enter your Seconds:-500
# Hours:-1
# Minutes:51
# Seconds:40

# %%
#Class Evaluation Task3

distance= int(input("Please, Enter your distance in meters:"))
time= int(input("Please, Enter your time in seconds"))
speed=0

if distance <0 or time <0:
  print("Distance or Time can not be Negative")
else:
  distance= distance/1000
  time= time /3600

speed= distance / time

print(f"{speed} km/h")

if speed <60:
  print("Too slow. It needs more changes.")
elif 60<= speed <= 90:
  print("Velocity is okay. The car is ready!")
else:
  print("Too fast. Only a few changes should suffice.")
# Out:
# Please, Enter your distance in meters:25400
# Please, Enter your time in seconds3600
# 25.4 km/h
# Too slow. It needs more changes.

# %% [markdown]
# **HOME TASK**

# %%
#1

number1=int(input("Please, enter your first number: "))
number2=int(input("Please, enter your second number: "))
result=0
if number1 > number2:
  sub= number1- number2

elif number2 > number1:
  sub= number2 - number1

else:
  sub= number1-number2

print(result)
# Out:
# Please, enter your first number: 20
# Please, enter your second number: 20
# 0

# %%
#Task1

number1=int(input("Please, enter your first number: "))
number2=int(input("Please, enter your second number: "))
result=0
if number1 == number2:
  result= number1-number2

elif number2 > number1:
  result= number2 - number1

else:
  result= number1 - number2

print(result)
# Out:
# Please, enter your first number: 8
# Please, enter your second number: 8
# 0

# %%
#Task2

num=int(input("Enter your number:"))

if (num%2==0) and (num%5==0):
  print("Multiple of 2 and 5 both")
#elif (num%2==0) and (num%5!=0):
  #print()
elif (num%2 != 0) and (num%5 != 0):
  print("Not a multiple we want")
else:
  print(num)
# Out:
# Enter your number:5
# 5

# %%
#Task3

s=int(input("Please, enter your number:"))
L=0
if s <100:
  L= 3000 - 125 *(s**2)
else:
  L= 12000 /(4+(s**2)/14900)
print(L)
# Out:
# Please, enter your number:3
# 1875

# %%
#task4

hour=int(input("Please enter your hours between 0 to 23:"))

if (hour <0) or (hour >23):
  print("Wrong time")

elif 4<= hour <=6:
  print("Breakfast")

elif 12 <= hour <= 13:
  print("Lunch")

elif 16<= hour <=17:
  print("Snacks")

elif 19 <= hour <=20:
  print("Dinner")

else:
  print("Patience is a virtue")
# Out:
# Please enter your hours between 0 to 23:19
# Dinner

# %%
#Task5

mark=int(input("Please, enter your mark: "))

if mark <0 or mark >100:
  print("Invalid Marks. Please Try again.")

elif mark >= 90:
  print("A")

elif 80<= mark <=89:
  print("B")

elif 70<= mark <=79:
  print("C")

elif 60<= mark <=69:
  print("D")

elif 50<= mark <=59:
  print("E")

else:
  print("F")
# Out:
# Please, enter your mark: 176
# Invalid Marks. Please Try again.

# %%
num1 = 10
num2 = -3
num3 = -1

sum = num1 + num2 + num3

if (num3 < 0):
    print(num3 * -2)
else:
    print(sum)
if (num1 < 5):
    print(num1 + 10)
elif (num2 == -3):
    num2 = num1
    print(num2)
else:
    print(num1 + num2 + num3)
if (num1 > 15):
    print(num1)
elif (num2 == 0):
    print(num2 + num3)
else:
    print(num3)
if (sum != 0):
    print(100)
else:
    print(sum + 100)
if (num1 > 0 and num2 < 0):
    print(num1 == num2)
else:
    print("False")
# Out:
# 2
# 10
# -1
# 100
# False

# %%
1
var1 = False
2
var2 = False
3
var3 = False
4
var4 = False
5
var5 = False
6
var6 = False
7
result1 = False
8
result2 = False
9
result3 = False
10
result4 = False
11
result5 = False
12
result6 = False
13
result7 = False
14
result8 = False
15
result9 = False
16
result10 = False
17
var1 = ((not True) or True) and False
18
var2 = var1 and False
19
var3 = True and not False
20
var4 = False
21
var5 = True
22
var6 = var3 and False
23
result1 = (var1 and var2) and (40 % 3) > 45 or (var5 and var6)
24
result2 = (var1 or var2) or (result1 and False)
25
result3 = (var1 and result1) or result2 or var5
26
result4 = (var1 or var2) or ((var3 and var1) and False)
27
result5 = (var1 and var2) and (result3 or var1)
28
result6 = ((var3 or (not var2)) and (result5)) or True
29
result7 = (var4 and result1) and ((result1 and False) or True)
30
result8 = ((var1 and result3) and ((not var5) or var6)) and True
31
result9 = ((result2 and var2) or ((not result7) and var1)) and not False
32
result10 = not(var1 and True)

print(result1)
print(result2)
print(result3)
print(result4)
print(result5)
print(result6)
print(result7)
print(result8)
print(result9)
print(result10)
# Out:
# False
# False
# True
# False
# False
# True
# False
# False
# False
# True

# %%
var1 = var2 = var3 = var4 = var5 = var6 = False
result1 = result2 = result3 = result4 = result5 = result6 = False
result7 = result8 = result9 = result10 = False
var1 = (not False or False) and True
var2 = var1 and True
var3 = False and not True
var4 = True
var5 = False
var6 = var3 and True
result1 = (var1 and var2) and ( 40 % 3 > 45) or (var5 and var6)
result2 = (var1 or var2) or (result1 and False)
result3 = (var1 and result1) or result2 or var5
result4 = (var1 or var2) or ((var3 and var1) and False)
result5 = (var1 and var2) and (result3 or var1)
result6 = ((var3 or not var2) and (result5)) or True
result7 = (var4 and result1) and ((result1 and False) or True)
result8 = ((var1 and result3) and (not var5 or var6)) and True
result9 = ((result2 and var2) or (not result7 and var1)) and not False
result10 = not (var1 and True)

print(result1)
print(result2)
print(result3)
print(result4)
print(result5)
print(result6)
print(result7)
print(result8)
print(result9)
print(result10)
# Out:
# False
# True
# True
# True
# True
# True
# False
# True
# True
# False
