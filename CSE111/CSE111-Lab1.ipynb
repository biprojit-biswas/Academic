# %% [markdown]
# **Task1**

# %%
st=input("Enter your word:")
up=0
low=0

# %%
user = input("Enter  a string: ")
upper_case = 0
lower_case = 0
new_word=""
for i in user:
    if 65<= ord(i) <=90:
         upper_case+= 1
    elif 97<= ord(i) <=122:
        lower_case += 1

'''def caseConverter(user):
    if len(upper_case)> len(lower_case):
        #return user.upper()
    else:
        return user.lower()'''

if upper_case>lower_case:
  for i in range (len(user)):
    if 65<= ord(user[i]) <=90:
      new_word+= (user[i])
    else:
      new_word= new_word+ chr(ord(user[i])-32)
else:
  for i in range(len(user)):
    if 97<= ord(user[i]) <=122:
      new_word+= str(user[i])
    else:
      new_word= new_word+ chr(ord(user[i])+32)


print(new_word)
#result = caseConverter(user)
#print(result)
# Out:
# Enter  a string: House
# house

# %%
user = input("Enter  a string: ")
up=0
low=0
for i in user:
    if 65<= ord(i) <=90:
        upper_case += i
    else:
        lower_case += i

if up>low:
  for k in user:
    if 65<= ord(k)<=95:
# Out:
# Enter  a string: HOusE
# househousehouse

# %%
if len(bigstr)>len(smolstr):
   for i in str1:
     if 65<=ord(i)<=95:
       str2 += i
     else:
       str2 += chr(ord(i)-32)
   print(str2)

else:
   for i in str1:
     if 65<=ord(i)<=95:
      str3 += chr(ord(i)+32)
     else:
       str3 +=i
   print(str3)

# %%
#Task2


user = input("Enter a string: ")

numbers = '0123456789'
count = 0

for i in user:
    if i in numbers:
        count += 1

if count == 0:
    print("WORD")

elif count < len(user) or count > len(user):
    print("MIXED")

else:
    print("NUMBER")
# Out:
# Enter a string: 2343556
# NUMBER

# %%
#Task1

str1 = "HOusE"
smolstr = ""
bigstr = ""
str2 = ''
str3 = ''

for i in str1:
   if 65<=ord(i)<=90:
     bigstr += i
   else:
     smolstr += i
if len(bigstr)>len(smolstr):
   for i in str1:
     if 65<=ord(i)<=95:
       str2 += i
     else:
       str2 += chr(ord(i)-32)
   print(str2)

else:
   for i in str1:
     if 65<=ord(i)<=95:
       str3 += chr(ord(i)+32)
     else:
       str3 += i
   print(str3)
# Out:
# HOUSE

# %%
#task3

user = input('Enter a string: ')
newString = ''
firstUpper = 0
seconUpper = 0
for i in range(0,len(user)):
    if 65<= ord(user[i]) <= 90:
        firstUpper = i
        break
for i in range(firstUpper+1,len(user)):
    if 65<= ord(user[i]) <= 90:
        secondUpper = i
        break
for i in range(firstUpper+1,secondUpper):
    newString += user[i]
if len(newString) == 0:
    print('BLANK')
else:
    print(newString)
# Out:
# Enter a string: baNgladEsh
# glad

# %%
#TASK4

user = input("Enter string separeted by comma: ").split(",")

newString = ''
firstElement = user[0]
secondElement = user[1]

for i in firstElement:
    if i in secondElement:
        newString += i
for i in secondElement:
    if i in firstElement:
        newString += i

if newString == "":
    print('Nothing in common.')
else:
    print(newString)
# Out:
# Enter string separeted by comma: harry, hermione
# hrrhr

# %%
#TASK4

user=input("Enter string with coma:")
newstring=""
n1=""
n2=""
for i in range(0,len(user)):
  if (65<=ord(user[i])<=90) or (97<=ord(user[i])<=122):
    n1+=user[i]

    if ord(user[i])==44:
      break
for j in range(-1,-(len(user)+1)):
  if (65<=ord(user[i])<=90) or (97<=ord(user[i])<=122):
    n2+=user[i]
    if ord(user[i])==44:
      break
for i in firstElement:
    if i in secondElement:
        newString += i
for i in secondElement:
    if i in firstElement:
        newString += i

if newString == "":
    print('Nothing in common.')
else:
    print(newString)
# Out:
# Enter string with coma:harry, hermione
# hrrhrhrrhr

# %%
#TASK4

user=input("Enter string with coma:")
newstring=""
n1=""
#n2=""
for i in range(0,len(user)):
  if ord(user[i])==44:
      pass
  else:
    newstring+=user[i]
'''for j in range(-1,-(len(user)+1)):
  if (65<=ord(user[i])<=90) or (97<=ord(user[i])<=122):
    n2+=user[i]
    if ord(user[i])==44:
      break'''
'''for i in firstElement:
    if i in secondElement:
        newString += i
for i in secondElement:
    if i in firstElement:
        newString += i'''
for j in newstring:
  for k in newstring:
    if i == j:
      n1+=j

if n1 == "":
    print('Nothing in common.')
else:
    print(n1)
# Out:
# Enter string with coma:harry, hermione
# Nothing in common.

# %%
#Task5

user = input('Enter your password: ')

lower_count = 0
upper_count = 0
digit_count = 0
character_count = 0
error = ''

for i in user:
    if ord("a") <= ord(i) <= ord("z"):
        lower_count += 1
    elif ord("A") <= ord(i) <= ord("Z"):
        upper_count += 1
    elif ord("0") <= ord(i) <= ord("9"):
        digit_count += 1
    else:
        character_count += 1

if lower_count == 0:
    error += "Lowercase character missing, "
if upper_count == 0:
    error += "Uppercase character missing, "
if digit_count == 0:
    error += "Digit character missing, "
if character_count == 0:
    error += "Special character missing "

if error == '':
    print("OK")
else:
    print(error)
# Out:
# Enter your password: ohmybracu
# Uppercase character missing, Digit character missing, Special character missing

# %%
#TASK4

user=input("Enter string with coma:")

# %% [markdown]
# **LIST**

# %%
#TASK1

myList = []
while  True :
    user = input()
    if user != 'STOP':
      myList.append(int(user))
    if user == 'STOP':
      break

list2 = []
for i in myList:
  if i not in list2:
    list2.append(i)

for item in list2:
  count= 0
  for j in myList:
    if item == j:
      count += 1
  print(item,count,'times')
# Out:
# 10
# 20
# 20
# 30
# 10
# 50
# 90
# STOP
# 10 2 times
# 20 2 times
# 30 1 times
# 50 1 times
# 90 1 times

# %%
#TASK2

listNumber = int(input("Enter the number of list: "))

maxSum = 0
maxList = []
def sumList(user):
    global maxSum,maxList
    listSum = 0
    for i in user:
        listSum += int(i)
    if listSum > maxSum:
        maxSum = listSum
        maxList = user

    return maxList and maxSum

for i in range(listNumber):
    user =  input('Enter your list of numbers: ').split()
    sumList(user)

finalList = []
for i in maxList:
    finalList.append(int(i))
print(maxSum)
print(finalList)
# Out:
# Enter the number of list: 4
# Enter your list of numbers: 1 2 3
# Enter your list of numbers: 4 5 6
# Enter your list of numbers: 10 11 12
# Enter your list of numbers: 7 8 9
# 33
# [10, 11, 12]

# %%
#TASK3

myList = []

user_list1 = input('Enter your first list: ').split()
user_list2 = input('Enter your second list: ').split()

for i in user_list1:
    for j in user_list2:
        mult = int(i) * int(j)
        myList.append(mult)

print(myList)
# Out:
# Enter your first list: 2 3 4
# Enter your second list: 3 4 5
# [6, 8, 10, 9, 12, 15, 12, 16, 20]

# %%
#TASK4
while True:
    user = input("Enter your list: ")
    if user == "STOP":
        break
    else:
        user = user.split()
        newList = []
        for i in user:
            newList.append(int(i))
        N = len(newList)
        for i in range(0,len(newList)-1):
            diff = newList[i+1] - newList[i]
            if diff < N:
                result = 'UB Jumper'
            else:
                result = 'Not UB Jumper'
        print(result)
# Out:
# Enter your list: 1 4 2 3
# UB Jumper
# Enter your list: 2 1 4 6 10
# UB Jumper
# Enter your list: 1 4 2 -1 6
# Not UB Jumper
# Enter your list: STOP

# %%
#TASK5

user_input1 = input("Enter the number of members and number of participation: ").split()
user_input2 = input("Enter the member participaton: ").split()

mem = ''
for i in user_input2:
    if int(user_input1[1]) + int(i) <= 5:
        mem += i

if len(mem) == 0:
    print(0)
else:
    result = len(mem)//3
    print(result)
# Out:
# Enter the number of members and number of participation: 6 5
# Enter the member participaton: 0 0 0 0 0 0
# 2

# %% [markdown]
# **Dictionary**

# %%
#TASK1

user_input1 = {"a":  100, 'b': 100, 'c': 200, 'd': 300}
user_input2 = {"a": 300, 'b': 200, 'd': 400, 'e':  200}

newDict = {}

for i in user_input1.keys():
    if i in user_input2.keys():
        newDict[i] = user_input1[i] + user_input2 [i]
    else:
        newDict[i] = user_input1[i]
for i in user_input2.keys():
    if i not in newDict:
        newDict[i] = user_input2[i]

newList = []
for val in newDict.values():
    if val not in newList:
        newList.append(val)

for i in range(len(newList)):
    for j in range(0,len(newList)-i,-1):
        if newList[j] > newList[j+1]:
            newList[j],newList[j+1] = newList[j+1],newList[j]
print(newList)
print(newDict)
# Out:
# [400, 300, 200, 700]
# {'a': 400, 'b': 300, 'c': 200, 'd': 700, 'e': 200}

# %%
#task2

print("Enter STOP to break")
myDict = {}
while True:
    user = input("Enter your number: ")
    if user == "STOP":
        break
    else:
        if user not in myDict:
            myDict[user] = 1
        else:
            myDict[user] += 1

for i in myDict.keys():
  print(f"{i} - {myDict[i]} times")
# Out:
# Enter STOP to break
# Enter your number: 10
# Enter your number: 10
# Enter your number: 10
# Enter your number: 30
# Enter your number: 20
# Enter your number: 30
# Enter your number: 40
# Enter your number: 30
# Enter your number: 70
# Enter your number: STOP
# 10 - 3 times
# 30 - 3 times
# 20 - 1 times
# 40 - 1 times
# 70 - 1 times

# %%
#task3

input_Dict = {'key1' : 'value1', 'key2' : 'value2', 'key3' : 'value1'}

newDict = {}
for key,val in input_Dict.items():
    if val not in newDict:
        newDict[val] = [key]
    else:
        newDict[val].append(key)

print(newDict)
# Out:
# {'value1': ['key1', 'key3'], 'value2': ['key2']}

# %%
#Task

dict = {1:'.,?!:' ,2:'ABC' ,3:'DEF' ,4:'GHI' ,5:'JKL' ,6:'MNO' ,7:'PQRS' ,8:'TUV' ,9:'WXYZ' ,0:'Space' }

user = input("Enter your message: ")
string = ''
for i in user:
    if 65 <= ord(i) <= 90:
        string += i
    elif 97 <= ord(i) <=122:
        string += chr(ord(i)-32)
    else:
        string += i


key_mapping = {
    ".": 1, ",": 11, "?": 111, "!": 1111, ":": 11111,
    "A": 2, "B": 22, "C": 222,
    "D": 3, "E": 33, "F": 333,
    "G": 4, "H": 44, "I": 444,
    "J": 5, "K": 55, "L": 555,
    "M": 6, "N": 66, "O": 666,
    "P": 7, "Q": 77, "R": 777, "S": 7777,
    "T": 8, "U": 88, "V": 888,
    "W": 9, "X": 99, "Y": 999, "Z": 9999,
    " ": 0
}
for char in string:
    key = key_mapping[char]
    print(key,end='')
# Out:
# Enter your message: Hello, World!
# 4433555555666110966677755531111

# %%
#STring4

user=input()
q=""

for j in range (len(m)):
  if ord(m[j])== ord(","):
    n=m[:j]
    s=m[j+2:]
print(n)
print(s)

for i in n:
  if i in s:
    q+=i

for l in s:
  if l in n:
    q+=l

if q=="":
  print("No")
else:
  print(q)
# Out:
# dean, tom
# dean
# tom
# No

# %%
day = int(input("Enter the number of days: "))
def timeCalculator(day):
  years = day//365
  months = (day-(years*365))//30
  days = (day-(years*365)) % 30
  print(years,"years",months,"months",days,"days")

  print(f"")

timeCalculator(day)
